# %% [markdown]
# # 1. Data and Library Load

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import os
import random

# ML
from sklearn.ensemble import RandomForestRegressor  # Bagging
from xgboost.sklearn import XGBRFRegressor           # GBM
from sklearn.linear_model import LogisticRegression  # LogisticRegression


# DL
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, ReLU, Softmax, Dropout
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# for checking multi-collinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# KFold(CV), partial : for optuna
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from functools import partial
from imblearn.over_sampling import SMOTE

# AutoML framework
import optuna
from optuna.samplers import TPESampler

# %%
# set configs
is_tuning = True
if is_tuning:
    sampler = TPESampler(seed=42)  # Make the sampler behave in a deterministic way.
is_scaling = True
is_pca = False
apply_vif = False
is_cuml = True
is_debug = True
sampling_method = 'hybrid' # 'under' or 'over'
if is_tuning:
    n_trials=50

# import SVC
# if is_cuml:
#     from cuml.svm import SVC, LinearSVC
# else:
#     from sklearn.svm import SVC
    
from sklearn.svm import SVC

    
# Keras model compile
learning_rate = 1e-2
batch_size = 32
epochs = 10

# %%
train = pd.read_csv('/USER/teeth/train.csv')
test = pd.read_csv('/USER/teeth/test.csv')

print(train.shape, test.shape)
# Out:
# (432, 12) (286, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   filename   432 non-null    object
#  1   operator   432 non-null    object
#  2   date       432 non-null    object
#  3   ID         432 non-null    object
#  4   sex        432 non-null    object
#  5   age        432 non-null    int64
#  6   ext_tooth  432 non-null    int64
#  7   time_min   432 non-null    int64
#  8   mmo        432 non-null    int64
#  9   height     427 non-null    float64
#  10  weight     427 non-null    float64
#  11  bmi        427 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 40.6+ KB

# %% [markdown]
# # 2. EDA

# %%
lb = LabelEncoder()
train.sex = lb.fit_transform(train.sex)  # M->0, F->1

# %%
train = train.drop(columns=["ID","filename","ext_tooth","date"])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   operator  432 non-null    object
#  1   sex       432 non-null    int64
#  2   age       432 non-null    int64
#  3   time_min  432 non-null    int64
#  4   mmo       432 non-null    int64
#  5   height    427 non-null    float64
#  6   weight    427 non-null    float64
#  7   bmi       427 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 27.1+ KB

# %%
# 결측치 채우기
train.loc[train['height'] != train['height'], 'height'] = train['height'].mean()
train.loc[train['weight'] != train['weight'], 'weight'] = train['weight'].mean()
train.loc[train['bmi'] != train['bmi'], 'bmi'] = train['bmi'].mean()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   operator  432 non-null    object
#  1   sex       432 non-null    int64
#  2   age       432 non-null    int64
#  3   time_min  432 non-null    int64
#  4   mmo       432 non-null    int64
#  5   height    432 non-null    float64
#  6   weight    432 non-null    float64
#  7   bmi       432 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 27.1+ KB

# %%
train[['A','K','P','Y']] = pd.get_dummies(train['operator'], dtype=int)

# %%
train = train.drop(columns=["operator"])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sex       432 non-null    int64
#  1   age       432 non-null    int64
#  2   time_min  432 non-null    int64
#  3   mmo       432 non-null    int64
#  4   height    432 non-null    float64
#  5   weight    432 non-null    float64
#  6   bmi       432 non-null    float64
#  7   A         432 non-null    int64
#  8   K         432 non-null    int64
#  9   P         432 non-null    int64
#  10  Y         432 non-null    int64
# dtypes: float64(3), int64(8)
# memory usage: 37.3 KB

# %%
# check missing data
train[train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [sex, age, time_min, mmo, height, weight, bmi, A, K, P, Y]
# Index: []

# %%
def check_vif(df):
    vifs = [variance_inflation_factor(df, i) for i in range(df.shape[1])]
    vif_df = pd.DataFrame({"features":df.columns, "VIF" : vifs})
    vif_df = vif_df.sort_values(by="VIF", ascending=False)
    remove_col = vif_df.iloc[0, 0]
    top_vif = vif_df.iloc[0, 1]
    return vif_df, remove_col, top_vif

# %%
# remove all features when VIF is over 10.
apply_vif = False
if apply_vif:
    top_vif = 100

    while(top_vif > 5):
        vif_df, remove_col, top_vif = check_vif(train)
        print(remove_col, top_vif)
        if top_vif < 5:
            break
        train = train.drop(columns=remove_col)

    display(train)

# %%
# feature selection via Feature Importance
X = train.drop(columns=["time_min"])
y = train['time_min']

rf = RandomForestRegressor()
rf.fit(X, y)
fi_df = pd.DataFrame({'feature':X.columns, 'importance':rf.feature_importances_})
selected_cols = fi_df.sort_values(by="importance", ascending=False)[:10]["feature"].values
selected_cols
# Out:
# array(['Y', 'age', 'bmi', 'height', 'mmo', 'weight', 'A', 'sex', 'P', 'K'],
#       dtype=object)

# %% [markdown]
# # 3. Data preprocessing

# %%
selected_cols = ['sex', 'age', 'mmo', 'height', 'weight', 'bmi', 'A', 'K','P', 'Y']
target_cols = ['time_min']

# %%
from sklearn.model_selection import train_test_split

#X = train.drop(columns=["Class"])
X = train[selected_cols]
y = train['time_min']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (367, 10) (65, 10) (367,) (65,)

# %%
from sklearn.preprocessing import StandardScaler

if is_scaling:
    scaler = StandardScaler()
    data_ = scaler.fit_transform(X_train)
    X_train = pd.DataFrame(data=data_, columns=X_train.columns)
    data_ = scaler.transform(X_val)
    X_val = pd.DataFrame(data=data_, columns=X_val.columns)
    display(X_train)
# Out:
#           sex       age       mmo    height    weight       bmi         A  \
# 0    1.013718  0.719932  0.187817 -0.175799 -0.248856 -0.182346 -0.864650
# 1    1.013718  1.256046  0.002025  0.778479  1.999712  1.997820  1.156538
# 2   -0.986468 -0.888411  1.488359 -0.772222 -1.119270 -1.036708 -0.864650
# 3    1.013718  1.166694  1.859943  1.374902  0.911695  0.318402 -0.864650
# 4   -0.986468 -0.441649  0.002025 -0.414368 -0.466460 -0.333549 -0.864650
# ..        ...       ...       ...       ...       ...       ...       ...
# 362 -0.986468  1.434751 -1.484309 -0.891507 -0.829132 -0.561180  1.156538
# 363  1.013718 -0.977763  0.930984  2.090610  1.709574  0.762472 -0.864650
# 364  1.013718 -0.441649 -0.555350  1.494187  1.129299  0.492714  1.156538
# 365 -0.986468  0.005113  1.302567 -1.607215 -1.046735 -0.460847 -0.864650
# 366 -0.986468  2.238923  0.002025 -1.368646 -0.611529  0.048725 -0.864650
#
#             K         P         Y
# 0   -0.536395  2.674987 -0.540605
# 1   -0.536395 -0.373834 -0.540605
# 2    1.864299 -0.373834 -0.540605
# 3   -0.536395  2.674987 -0.540605
# 4    1.864299 -0.373834 -0.540605
# ..        ...       ...       ...
# 362 -0.536395 -0.373834 -0.540605
# 363 -0.536395  2.674987 -0.540605
# 364 -0.536395 -0.373834 -0.540605
# 365 -0.536395  2.674987 -0.540605
# 366 -0.536395  2.674987 -0.540605
#
# [367 rows x 10 columns]

# %%
if is_pca:
    from sklearn.decomposition import PCA
    
    pca = PCA(n_components=0.90, random_state=42)
    data_ = pca.fit_transform(X_train)
    X_train = pd.DataFrame(data=data_, columns=[f"PC{i}" for i in range(1, data_.shape[1]+1)])
    data_ = pca.transform(X_val)
    X_val = pd.DataFrame(data=data_, columns=[f"PC{i}" for i in range(1, data_.shape[1]+1)])

    display(X_train)

# %% [markdown]
# # 4. Fitting and Evaluation

# %%
# from sklearn.metrics import mean_absolute_error
# evaluation_metric = balance_logloss

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

def rf_optimizer(trial, X, y, K):
    # define parameter to tune
    n_estimators = trial.suggest_categorical('n_estimators', [50, 100, 200])
    max_depth = trial.suggest_int('max_depth', 4, 10)
    max_features = trial.suggest_categorical('max_features', [0.6, 0.7, 0.8])
    
    
    # set model
    model = RandomForestRegressor(n_estimators=n_estimators,
                                   max_depth=max_depth,
                                   max_features=max_features,
                                   criterion='absolute_error', # log_loss
                                #    class_weight='balanced'
                                  )
    
    # K-Fold Cross validation
    folds = StratifiedKFold(n_splits=K, shuffle=True)
    losses = []
    
    for train_idx, val_idx in folds.split(X, y):
        X_train = X.iloc[train_idx, :]
        y_train = y.iloc[train_idx]
        
        X_val = X.iloc[val_idx, :]
        y_val = y.iloc[val_idx]
        
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        loss = mean_absolute_percentage_error(y_val, preds)
        losses.append(loss)
    
    
    # return mean score of CV
    return np.mean(losses)

# %%
def xgb_optimizer(trial, X, y, K):
    n_estimators = trial.suggest_categorical('n_estimators', [500, 1000, 2000])
    max_depth = trial.suggest_int('max_depth', 4, 10)
    colsample_bytree = trial.suggest_categorical('colsample_bytree', [0.5, 0.6, 0.7, 0.8])
    learning_rate = trial.suggest_float('learning_rate', 1e-3, 1e-2)
    reg_lambda = trial.suggest_categorical('reg_lambda', [0.1, 0.5, 1, 2])
    
    
    model = XGBRFRegressor(n_estimators=n_estimators,
                          max_depth=max_depth,
                          colsample_bytree=colsample_bytree,
                          learning_rate=learning_rate,
                          reg_lambda=reg_lambda)
#                          scale_pos_weight=4.71)  ## we set class imbalance by using sampling method.
    
    
    folds = StratifiedKFold(n_splits=K, shuffle=True)
    losses = []
    
    for train_idx, val_idx in folds.split(X, y):
        X_train = X.iloc[train_idx, :]
        y_train = y.iloc[train_idx]
        
        X_val = X.iloc[val_idx, :]
        y_val = y.iloc[val_idx]
        
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        loss = mean_absolute_percentage_error(y_val, preds)
        losses.append(loss)
    
    
    return np.mean(losses)

# %%
K = 4 # set K of K-Fold
opt_func = partial(rf_optimizer, X=X, y=y, K=K)

if is_tuning:
    rf_study = optuna.create_study(direction="minimize", sampler=sampler) # determine minimize or maximize sth
    rf_study.optimize(opt_func, n_trials=n_trials)
# Out:
# [I 2023-11-23 13:04:18,242] A new study created in memory with name: no-name-33e8b61b-5d87-442d-8bff-0c88f9103a5c
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:19,325] Trial 0 finished with value: 4.873645833333333 and parameters: {'n_estimators': 100, 'max_depth': 8, 'max_features': 0.6}. Best is trial 0 with value: 4.873645833333333.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:19,729] Trial 1 finished with value: 4.6673379629629625 and parameters: {'n_estimators': 50, 'max_depth': 4, 'max_features': 0.6}. Best is trial 1 with value: 4.6673379629629625.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:22,073] Trial 2 finished with value: 4.852447916666666 and parameters: {'n_estimators': 200, 'max_depth': 7, 'max_features': 0.8}. Best is trial 1 with value: 4.6673379629629625.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04
 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:46,364] Trial 31 finished with value: 4.772662037037037 and parameters: {'n_estimators': 100, 'max_depth': 6, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:47,228] Trial 32 finished with value: 4.741006944444444 and parameters: {'n_estimators': 100, 'max_depth': 5, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:48,010] Trial 33 finished with value: 4.6260763888888885 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:49,003] Trial 34 finished with value: 4.842905092592592 and parameters: {'n_estimators': 100, 'max_depth': 7, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:50,702] Trial 35 finished with value: 4.714837962962963 and parameters: {'n_estimators': 200, 'max_depth': 5, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:51,956] Trial 36 finished with value: 4.845706018518519 and parameters: {'n_estimators': 100, 'max_depth': 8, 'max_features': 0.8}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:52,432] Trial 37 finished with value: 4.780740740740741 and parameters: {'n_estimators': 50, 'max_depth': 6, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:54,759] Trial 38 finished with value: 4.749971064814815 and parameters: {'n_estimators': 200, 'max_depth': 7, 'max_features': 0.8}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:55,539] Trial 39 finished with value: 4.668506944444443 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:56,052] Trial 40 finished with value: 4.782384259259259 and parameters: {'n_estimators': 50, 'max_depth': 5, 'max_features': 0.8}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:56,835] Trial 41 finished with value: 4.609467592592592 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 27 with value: 4.5945833333333335.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:57,614] Trial 42 finished with value: 4.577256944444444 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:58,391] Trial 43 finished with value: 4.598981481481482 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:59,174] Trial 44 finished with value: 4.650486111111111 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:04:59,958] Trial 45 finished with value: 4.638842592592593 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:00,862] Trial 46 finished with value: 4.641273148148148 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.8}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:01,704] Trial 47 finished with value: 4.636712962962963 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.7}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:02,488] Trial 48 finished with value: 4.702986111111111 and parameters: {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:03,598] Trial 49 finished with value: 4.745231481481481 and parameters: {'n_estimators': 100, 'max_depth': 9, 'max_features': 0.6}. Best is trial 42 with value: 4.577256944444444.

# %%
K = 4
opt_func = partial(xgb_optimizer, X=X, y=y, K=K)

if is_tuning:
    xgb_study = optuna.create_study(direction="minimize", sampler=sampler)
    xgb_study.optimize(opt_func, n_trials=n_trials)
# Out:
# [I 2023-11-23 13:05:03,665] A new study created in memory with name: no-name-64461f1b-08dc-4d77-a8b8-72344a7d0ddc
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:05,463] Trial 0 finished with value: 6.239804111145161 and parameters: {'n_estimators': 500, 'max_depth': 9, 'colsample_bytree': 0.7, 'learning_rate': 0.004226191556898453, 'reg_lambda': 0.5}. Best is trial 0 with value: 6.239804111145161.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:11,681] Trial 1 finished with value: 6.233454863230388 and parameters: {'n_estimators': 2000, 'max_depth': 9, 'colsample_bytree': 0.6, 'learning_rate': 0.0074192030850069556, 'reg_lambda': 1}. Best is trial 1 with value: 6.233454863230388.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:12,251] Trial 2 finished with value: 6.23047090680511 and parameters: {'n_estimators': 500, 'max_depth': 4, 'colsample_bytree': 0.6, 'learning_rate': 0.009168098265334837, 'reg_lambda': 1}. Best is trial 2 with value: 6.23047090680511.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:15,702] Trial 3 finished with value: 6.243838023256373 and parameters: {'n_estimators': 1000, 'max_depth': 10, 'colsample_bytree': 0.7, 'learning_rate': 0.0026791305299743227, 'reg_lambda': 2}. Best is trial 2 with value: 6.23047090680511.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05:16,633] Trial 4 finished with value: 6.239931499516523 and parameters: {'n_estimators': 500, 'max_depth': 6, 'colsample_bytree': 0.6, 'learning_rate': 0.004756699028339011, 'reg_lambda': 2}. Best is trial 2 with value: 6.23047090680511.
# /root/anaconda3/envs/yeardream/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# [I 2023-11-23 13:05
# 29 0 days 00:00:02.277045                 8                  0.7
# 30 0 days 00:00:00.928502                 6                  0.6
# 31 0 days 00:00:00.927554                 6                  0.6
# 32 0 days 00:00:00.863540                 5                  0.6
# 33 0 days 00:00:00.779952                 4                  0.6
# 34 0 days 00:00:00.992435                 7                  0.6
# 35 0 days 00:00:01.698312                 5                  0.6
# 36 0 days 00:00:01.252835                 8                  0.8
# 37 0 days 00:00:00.474901                 6                  0.6
# 38 0 days 00:00:02.325975                 7                  0.8
# 39 0 days 00:00:00.778643                 4                  0.6
# 40 0 days 00:00:00.511754                 5                  0.8
# 41 0 days 00:00:00.781649                 4                  0.6
# 42 0 days 00:00:00.778397                 4                  0.6
# 43 0 days 00:00:00.776679                 4                  0.6
# 44 0 days 00:00:00.781702                 4                  0.6
# 45 0 days 00:00:00.783271                 4                  0.6
# 46 0 days 00:00:00.902596                 4                  0.8
# 47 0 days 00:00:00.840686                 4                  0.7
# 48 0 days 00:00:00.783269                 4                  0.6
# 49 0 days 00:00:01.109388                 9                  0.6
#
#     params_n_estimators     state
# 0                   100  COMPLETE
# 1                    50  COMPLETE
# 2                   200  COMPLETE
# 3                   200  COMPLETE
# 4                   200  COMPLETE
# 5                    50  COMPLETE
# 6                   100  COMPLETE
# 7                   100  COMPLETE
# 8                   100  COMPLETE
# 9                   200  COMPLETE
# 10                   50  COMPLETE
# 11                   50  COMPLETE
# 12                   50  COMPLETE
# 13                   50  COMPLETE
# 14                   50  COMPLETE
# 15                   50  COMPLETE
# 16                   50  COMPLETE
# 17                   50  COMPLETE
# 18                   50  COMPLETE
# 19                   50  COMPLETE
# 20                   50  COMPLETE
# 21                   50  COMPLETE
# 22                   50  COMPLETE
# 23                   50  COMPLETE
# 24                   50  COMPLETE
# 25                   50  COMPLETE
# 26                   50  COMPLETE
# 27                   50  COMPLETE
# 28                  100  COMPLETE
# 29                  200  COMPLETE
# 30                  100  COMPLETE
# 31                  100  COMPLETE
# 32                  100  COMPLETE
# 33                  100  COMPLETE
# 34                  100  COMPLETE
# 35                  200  COMPLETE
# 36                  100  COMPLETE
# 37                   50  COMPLETE
# 38                  200  COMPLETE
# 39                  100  COMPLETE
# 40                   50  COMPLETE
# 41                  100  COMPLETE
# 42                  100  COMPLETE
# 43                  100  COMPLETE
# 44                  100  COMPLETE
# 45                  100  COMPLETE
# 46                  100  COMPLETE
# 47                  100  COMPLETE
# 48                  100  COMPLETE
# 49                  100  COMPLETE
# Best Score: 4.5773
# Best params:  {'n_estimators': 100, 'max_depth': 4, 'max_features': 0.6}
#     number     value             datetime_start          datetime_complete  \
# 42      42  4.577257 2023-11-23 13:04:56.835736 2023-11-23 13:04:57.614133
#
#                  duration  params_max_depth  params_max_features  \
# 42 0 days 00:00:00.778397                 4                  0.6
#
#     params_n_estimators     state
# 42                  100  COMPLETE

# %%
if is_tuning:
    display_experiment_log(xgb_study)
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0
# 34 0 days 00:00:02.287473                      0.6              0.009300
# 35 0 days 00:00:03.399463                      0.8              0.008670
# 36 0 days 00:00:02.629147                      0.6              0.009345
# 37 0 days 00:00:07.339099                      0.7              0.009960
# 38 0 days 00:00:03.474968                      0.8              0.007756
# 39 0 days 00:00:03.832495                      0.5              0.009320
# 40 0 days 00:00:01.201865                      0.6              0.008704
# 41 0 days 00:00:01.526548                      0.8              0.009609
# 42 0 days 00:00:01.581332                      0.8              0.009991
# 43 0 days 00:00:01.758504                      0.8              0.009447
# 44 0 days 00:00:01.529614                      0.8              0.008953
# 45 0 days 00:00:01.505108                      0.8              0.009280
# 46 0 days 00:00:01.743269                      0.5              0.009620
# 47 0 days 00:00:01.927734                      0.8              0.008523
# 48 0 days 00:00:04.809360                      0.7              0.008091
# 49 0 days 00:00:01.523571                      0.8              0.009996
#
#     params_max_depth  params_n_estimators  params_reg_lambda     state
# 0                  9                  500                0.5  COMPLETE
# 1                  9                 2000                1.0  COMPLETE
# 2                  4                  500                1.0  COMPLETE
# 3                 10                 1000                2.0  COMPLETE
# 4                  6                  500                2.0  COMPLETE
# 5                  6                 2000                1.0  COMPLETE
# 6                  5                 2000                0.1  COMPLETE
# 7                  4                 1000                0.1  COMPLETE
# 8                  6                 2000                0.1  COMPLETE
# 9                  4                  500                0.5  COMPLETE
# 10                 8                  500                1.0  COMPLETE
# 11                 8                  500                1.0  COMPLETE
# 12                 8                  500                1.0  COMPLETE
# 13                 8                  500                1.0  COMPLETE
# 14                 8                  500                1.0  COMPLETE
# 15                 7                 1000                1.0  COMPLETE
# 16                10                  500                1.0  COMPLETE
# 17                 7                  500                0.5  COMPLETE
# 18                 9                  500                2.0  COMPLETE
# 19                 8                 1000                1.0  COMPLETE
# 20                 7                 1000                1.0  COMPLETE
# 21                 8                 1000                1.0  COMPLETE
# 22                 9                 1000                1.0  COMPLETE
# 23                 9                 1000                1.0  COMPLETE
# 24                10                 1000                1.0  COMPLETE
# 25                 9                 1000                1.0  COMPLETE
# 26                 9                 1000                0.5  COMPLETE
# 27                10                 1000                2.0  COMPLETE
# 28                 9                 1000                0.1  COMPLETE
# 29                 9                 1000                1.0  COMPLETE
# 30                10                 1000                0.5  COMPLETE
# 31                 8                 1000                1.0  COMPLETE
# 32                 8                 1000                1.0  COMPLETE
# 33                 9                 2000                1.0  COMPLETE
# 34                 7                 1000                1.0  COMPLETE
# 35                 9                 1000                1.0  COMPLETE
# 36                 8                 1000                2.0  COMPLETE
# 37                10                 2000                1.0  COMPLETE
# 38                 9                 1000                1.0  COMPLETE
# 39                 6                 2000                0.1  COMPLETE
# 40                 7                  500                1.0  COMPLETE
# 41                 8                  500                1.0  COMPLETE
# 42                 8                  500                1.0  COMPLETE
# 43                 9                  500                1.0  COMPLETE
# 44                 8                  500                1.0  COMPLETE
# 45                 8                  500                1.0  COMPLETE
# 46                 9                  500                0.1  COMPLETE
# 47                 6                 1000                2.0  COMPLETE
# 48                 7                 2000                0.5  COMPLETE
# 49                 8                  500                1.0  COMPLETE
# Best Score: 6.2239
# Best params:  {'n_estimators': 1000, 'max_depth': 8, 'colsample_bytree': 0.8, 'learning_rate': 0.009966161429329495, 'reg_lambda': 1}
#     number     value             datetime_start          datetime_complete  \
# 19      19  6.223905 2023-11-23 13:05:44.005680 2023-11-23 13:05:47.151601
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 19 0 days 00:00:03.145921                      0.8              0.009966
#
#     params_max_depth  params_n_estimators  params_reg_lambda     state
# 19                 8                 1000                1.0  COMPLETE

# %% [markdown]
# # 6. Test Prediction and Make Submission

# %%
test
# Out:
#           filename operator        date          ID  sex  age  ext_tooth  mmo  \
# 0    test_0000.png        A  2021.01.27  0025d728ca    1   25         38   42
# 1    test_0001.png        A  2020.03.10  0025254212    1   41         38   45
# 2    test_0002.png        K  2020.03.20  00c1240c5e    0   25         38   44
# 3    test_0003.png        A  2020.06.13  00afffb836    0   25         38   34
# 4    test_0004.png        P  2020.05.18  001075979c    1   21         38   50
# ..             ...      ...         ...         ...  ...  ...        ...  ...
# 281  test_0281.png        A  2020.08.21  000bd141a0    1   26         38   35
# 282  test_0282.png        A  2020.04.23  00ac217bb0    0   22         48   42
# 283  test_0283.png        Y  2021.02.03  002fb89e3a    1   21         48   40
# 284  test_0284.png        K  2021.03.13  0018cd0b04    0   25         38   38
# 285  test_0285.png        A  2020.09.01  00a498137c    1   16         38   42
#
#      height  weight        bmi  A  K  P  Y
# 0     178.0    79.0  24.933720  1  0  0  0
# 1     178.0    80.0  25.249337  1  0  0  0
# 2     162.0    71.0  27.053803  0  1  0  0
# 3     158.0    52.0  20.829995  1  0  0  0
# 4     178.0    67.0  21.146320  0  0  1  0
# ..      ...     ...        ... .. .. .. ..
# 281   174.0    54.0  17.835910  1  0  0  0
# 282   162.0    62.0  23.624447  1  0  0  0
# 283   179.0    81.0  25.280110  0  0  0  1
# 284   162.0    62.0  23.624447  0  1  0  0
# 285   184.0    83.0  24.515600  1  0  0  0
#
# [286 rows x 15 columns]

# %%
test.isna().sum()
# Out:
# filename     0
# operator     0
# date         0
# ID           0
# sex          0
# age          0
# ext_tooth    0
# mmo          0
# height       0
# weight       0
# bmi          0
# A            0
# K            0
# P            0
# Y            0
# dtype: int64

# %%
test.loc[test['height'] != test['height'], 'height'] = test['height'].mean()
test.loc[test['weight'] != test['weight'], 'weight'] = test['weight'].mean()
test.loc[test['bmi'] != test['bmi'], 'bmi'] = test['bmi'].mean()

# %%
test[['A','K','P','Y']] = pd.get_dummies(test['operator'], dtype=int)

# %%
test.sex = lb.fit_transform(test.sex)

# %%
test
# Out:
#           filename operator        date          ID  sex  age  ext_tooth  mmo  \
# 0    test_0000.png        A  2021.01.27  0025d728ca    1   25         38   42
# 1    test_0001.png        A  2020.03.10  0025254212    1   41         38   45
# 2    test_0002.png        K  2020.03.20  00c1240c5e    0   25         38   44
# 3    test_0003.png        A  2020.06.13  00afffb836    0   25         38   34
# 4    test_0004.png        P  2020.05.18  001075979c    1   21         38   50
# ..             ...      ...         ...         ...  ...  ...        ...  ...
# 281  test_0281.png        A  2020.08.21  000bd141a0    1   26         38   35
# 282  test_0282.png        A  2020.04.23  00ac217bb0    0   22         48   42
# 283  test_0283.png        Y  2021.02.03  002fb89e3a    1   21         48   40
# 284  test_0284.png        K  2021.03.13  0018cd0b04    0   25         38   38
# 285  test_0285.png        A  2020.09.01  00a498137c    1   16         38   42
#
#      height  weight        bmi  A  K  P  Y
# 0     178.0    79.0  24.933720  1  0  0  0
# 1     178.0    80.0  25.249337  1  0  0  0
# 2     162.0    71.0  27.053803  0  1  0  0
# 3     158.0    52.0  20.829995  1  0  0  0
# 4     178.0    67.0  21.146320  0  0  1  0
# ..      ...     ...        ... .. .. .. ..
# 281   174.0    54.0  17.835910  1  0  0  0
# 282   162.0    62.0  23.624447  1  0  0  0
# 283   179.0    81.0  25.280110  0  0  0  1
# 284   162.0    62.0  23.624447  0  1  0  0
# 285   184.0    83.0  24.515600  1  0  0  0
#
# [286 rows x 15 columns]

# %%
test.isna().sum()
# Out:
# filename     0
# operator     0
# date         0
# ID           0
# sex          0
# age          0
# ext_tooth    0
# mmo          0
# height       0
# weight       0
# bmi          0
# A            0
# K            0
# P            0
# Y            0
# dtype: int64

# %%
## preprocessing in same way
X_test = test[X.columns].fillna(X.mean())
if is_scaling:
    X_test = scaler.transform(X_test)
    X_test = pd.DataFrame(data=X_test, columns=X.columns)

if is_pca:
    data_ = pca.transform(X_test)
    X_test = pd.DataFrame(data=data_, columns=[f"PC{i}" for i in range(1, data_.shape[1]+1)])

X_test
# Out:
#           sex       age       mmo    height    weight       bmi         A  \
# 0    1.013718 -0.352297  0.373608  1.255617  1.056764  0.556759  1.156538
# 1    1.013718  1.077342  0.930984  1.255617  1.129299  0.640161  1.156538
# 2   -0.986468 -0.352297  0.745192 -0.652938  0.476488  1.116992 -0.864650
# 3   -0.986468 -0.352297 -1.112726 -1.130076 -0.901666 -0.527654  1.156538
# 4    1.013718 -0.709706  1.859943  1.255617  0.186351 -0.444065 -0.864650
# ..        ...       ...       ...       ...       ...       ...       ...
# 281  1.013718 -0.262944 -0.926934  0.778479 -0.756597 -1.318844  1.156538
# 282 -0.986468 -0.620354  0.373608 -0.652938 -0.176322  0.210782  1.156538
# 283  1.013718 -0.709706  0.002025  1.374902  1.201833  0.648293 -0.864650
# 284 -0.986468 -0.352297 -0.369559 -0.652938 -0.176322  0.210782 -0.864650
# 285  1.013718 -1.156468  0.373608  1.971326  1.346902  0.446270  1.156538
#
#             K         P         Y
# 0   -0.536395 -0.373834 -0.540605
# 1   -0.536395 -0.373834 -0.540605
# 2    1.864299 -0.373834 -0.540605
# 3   -0.536395 -0.373834 -0.540605
# 4   -0.536395  2.674987 -0.540605
# ..        ...       ...       ...
# 281 -0.536395 -0.373834 -0.540605
# 282 -0.536395 -0.373834 -0.540605
# 283 -0.536395 -0.373834  1.849780
# 284  1.864299 -0.373834 -0.540605
# 285 -0.536395 -0.373834 -0.540605
#
# [286 rows x 10 columns]

# %%
# Finalize Models
if is_tuning:
    rf_best_params = rf_study.best_params
    # lr_best_params = lr_study.best_params
    xgb_best_params = xgb_study.best_params

    best_rf = RandomForestRegressor(**rf_best_params)
    # best_lr = LogisticRegression(**lr_best_params)
    best_xgb = XGBRFRegressor(**xgb_best_params)

# %%
# first ensebmle model, then check it.
best_rf.fit(X_train, y_train)
# best_lr.fit(X_train, y_train)
best_xgb.fit(X_train, y_train)
# best_svm.fit(X_train, y_train)

# OOF-prediction
v_rf = best_rf.predict(X_val)
# v_lr = best_lr.predict_proba(X_val)
v_xgb = best_xgb.predict(X_val)
# v_svm = best_svm.predict_proba(X_val)
# print(v_rf.shape, v_lr.shape, v_xgb.shape, v_svm.shape)
print(v_rf.shape, v_xgb.shape)
# Out:
# (65,) (65,)

# %%
# model finalization and make prediction
best_rf.fit(X, y)
# best_lr.fit(X, y)
best_xgb.fit(X, y)
# best_svm.fit(X, y)

preds_rf = best_rf.predict(X_test)
# preds_lr = best_lr.predict(X_test)
preds_xgb = best_xgb.predict(X_test)
# preds_svm = best_svm.predict(X_test).values
# print(preds_rf.shape, preds_lr.shape, preds_xgb.shape, preds_svm.shape)
print(preds_rf.shape, preds_xgb.shape)
# Out:
# (286,) (286,)

# %%
v_rf = best_rf.predict(X_val)
# v_lr = best_lr.predict(X_val)
v_xgb = best_xgb.predict(X_val)
# v_svm = best_svm.predict(X_val).values
ensembles = np.mean([v_rf, v_xgb], axis=0)
ensembles = 0.7*v_rf+0.3*v_xgb
print("(After finalization)OOF prediction logloss : %.4f" % mean_absolute_percentage_error(y_val, ensembles))
# Out:
# (After finalization)OOF prediction logloss : 0.6642

# %%
preds_rf.shape
# Out:
# (286,)

# %%
submission = pd.read_csv('/USER/teeth/sample_submission.csv')
submission
# Out:
#           filename  time_min
# 0    test_0000.png         1
# 1    test_0001.png         1
# 2    test_0002.png         1
# 3    test_0003.png         1
# 4    test_0004.png         1
# ..             ...       ...
# 281  test_0281.png         1
# 282  test_0282.png         1
# 283  test_0283.png         1
# 284  test_0284.png         1
# 285  test_0285.png         1
#
# [286 rows x 2 columns]

# %%
voting_weights = [0.7, 0.3]
voting_weights = [1, 0]
submission['time_min'] = voting_weights[0]*preds_rf[:] + voting_weights[1]*preds_xgb[:]
submission
# Out:
#           filename   time_min
# 0    test_0000.png   8.919955
# 1    test_0001.png   8.919955
# 2    test_0002.png  13.715483
# 3    test_0003.png   8.546059
# 4    test_0004.png  14.756694
# ..             ...        ...
# 281  test_0281.png   8.919955
# 282  test_0282.png   8.546059
# 283  test_0283.png  16.832840
# 284  test_0284.png  13.715483
# 285  test_0285.png   8.919955
#
# [286 rows x 2 columns]

# %%
submission['time_min'].describe()
# Out:
# count    286.000000
# mean      11.848678
# std        3.269477
# min        8.546059
# 25%        8.919955
# 50%       11.317719
# 75%       14.710652
# max       16.832840
# Name: time_min, dtype: float64

# %%
submission.to_csv("submission.csv", index=False)
